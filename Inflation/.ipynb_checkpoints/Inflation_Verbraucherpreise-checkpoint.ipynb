# %%
# Inflation

# %%
# https://www.destatis.de/DE/Themen/Wirtschaft/Konjunkturindikatoren/Preise/pre110.html

# %%
from matplotlib import pyplot as plt
import pandas as pd
import os
from datetime import datetime
from datetime import date  # todays date
from matplotlib.ticker import FuncFormatter

# %%
# import

# %%
pfad = str(os.path.abspath(os.getcwd()))+ "\\"
size = 30
today = date.today().strftime("%d.%m.%Y")
titel0 = 'Inflation'
indexart = 'Verbraucherpreisindex'
print(pfad)
# Out:
# D:\Github\Aktien\Inflation\

# %%
df = pd.read_excel(pfad+"Input_Verbraucherpreise.xlsx")
df.rename(columns = {
    'Gesamt':'Gesamt', 
    'Nahrungsmittel (01)':'Nahrung',
    'Alkohol, Tabak (02)':'Alkohol_Tabak',
    'Kleidung (03)':'Kleidung',
    'Wohnung, Wasser, Strom, Gas, Brennstoffe (04)':'Wohnen',
    'Möbel, Haushaltsgeräte (05)':'Haushalt',
    'Gesundheit (06)':'Gesundheit',
    'Verkehr (07)':'Verkehr',
    'Post, Telekommunikation (08)':'Post_Internet',
    'Freizeit, Unterhaltung, Kultur (09)':'Freizeit',
    'Bildung (10)':'Bildung',
    'Gaststätten, Beherbergung, Dienstleistungen (11)':'Gastgewerbe',
    'Andere Waren, Dienstleistungen (12)':'andere_Waren_Dienstleistungen'}, 
    inplace = True)
df.head(2)
# Out:
#        Datum  Gesamt  Nahrung  Alkohol_Tabak  Kleidung  Wohnen  Haushalt  \
# 0 2022-07-01   118.4    129.2          123.1     103.4   119.5     113.5
# 1 2022-06-01   117.4    126.5          122.4     106.3   118.5     112.6
#
#    Gesundheit  Verkehr  Post_Internet  Freizeit  Bildung  Gastgewerbe  \
# 0       107.6    120.6           94.0     120.8    106.1        125.1
# 1       107.2    122.0           94.1     116.1    105.9        123.4
#
#    andere_Waren_Dienstleistungen  Geldmenge_M1  Geldmenge_M2  Geldmenge_M3
# 0                          114.6           NaN           NaN           NaN
# 1                          114.1           NaN           NaN           NaN

# %%
print(df.columns)
# Out:
# Index(['Datum', 'Gesamt', 'Nahrung', 'Alkohol_Tabak', 'Kleidung', 'Wohnen',
#        'Haushalt', 'Gesundheit', 'Verkehr', 'Post_Internet', 'Freizeit',
#        'Bildung', 'Gastgewerbe', 'andere_Waren_Dienstleistungen',
#        'Geldmenge_M1', 'Geldmenge_M2', 'Geldmenge_M3'],
#       dtype='object')

# %%
df.head(2)
# Out:
#        Datum  Gesamt  Nahrung  Alkohol_Tabak  Kleidung  Wohnen  Haushalt  \
# 0 2022-07-01   118.4    129.2          123.1     103.4   119.5     113.5
# 1 2022-06-01   117.4    126.5          122.4     106.3   118.5     112.6
#
#    Gesundheit  Verkehr  Post_Internet  Freizeit  Bildung  Gastgewerbe  \
# 0       107.6    120.6           94.0     120.8    106.1        125.1
# 1       107.2    122.0           94.1     116.1    105.9        123.4
#
#    andere_Waren_Dienstleistungen  Geldmenge_M1  Geldmenge_M2  Geldmenge_M3
# 0                          114.6           NaN           NaN           NaN
# 1                          114.1           NaN           NaN           NaN

# %%
for column in df[['Gesamt','Nahrung', 'Alkohol_Tabak', 'Kleidung', 
                  'Wohnen', 'Haushalt', 'Gesundheit', 'Verkehr', 
                  'Post_Internet', 'Freizeit', 'Bildung', 'Gastgewerbe', 'andere_Waren_Dienstleistungen', 
                  'Geldmenge_M1', 'Geldmenge_M2', 'Geldmenge_M3']]:
    title = column
    print(column)
    wert=df[f'{column}'].iat[0]
    print(wert)
    # print(df[column])

    def y_axis_thousands(x, pos):
        # 'The two args are the value and tick position'
        return '{:0,d}'.format(int(x)).replace(",", ".")

    plt.style.use('seaborn')
    fig, ax = plt.subplots(figsize=(16*1.2, 9))
    formatter = FuncFormatter(y_axis_thousands)
    ax.yaxis.set_major_formatter(formatter)
    plt.grid(True)

    plt.title(f'{titel0} - {title} {wert}%\n', fontsize=size * 1.5)
    plt.suptitle(f'{today} PW', fontsize=size * 0.7, y=0.915)

    if title == "Geldmenge_M1":
        plt.plot(df.Datum, df[f'Geldmenge_M2'], marker='', linestyle='-',
             color="black", linewidth=5, markersize=5, label="Geldmenge_M2")
        plt.plot(df.Datum, df[f'Geldmenge_M3'], marker='', linestyle='-',
             color="yellow", linewidth=5, markersize=5, label="Geldmenge_M3")
        plt.title(f'{titel0} - {title}\n', fontsize=size * 1.5)
        plt.suptitle(f'{today} PW', fontsize=size * 0.7, y=0.915)

    plt.plot(df.Datum, df[f'{title}'], marker='', linestyle='-',
             color="blue", linewidth=5, markersize=5, label=title)
    
    plt.plot(df.Datum, df['Gesamt'], marker='', linestyle='--',
             color="black", linewidth=3, label=indexart, markersize=5)
    
    plt.fill_between(df.Datum, df['Gesamt'], df[f'{title}'], color='green', alpha=0.5,
                    label='unter Verbraucherpreisindex', interpolate=True,
                    where = df['Gesamt'] > df[f'{title}'])
    
    plt.fill_between(df.Datum, df['Gesamt'], df[f'{title}'], color='red', alpha=0.5,
                    label='über Verbraucherpreisindex', interpolate=True,
                    where = df['Gesamt'] < df[f'{title}'])
    


    plt.xticks(fontsize=size * 0.7, rotation=0)
    plt.yticks(fontsize=size * 0.7, rotation=0)

    plt.ylabel(title, fontsize=size * 1)
    plt.xlabel('Zeit', fontsize=size * 1)



    
    plt.legend(loc='upper center',
           bbox_to_anchor=(0.5, -0.12),
           fancybox=True,
           shadow=True,
           ncol=2,
           fontsize=size * 1)
    
    ax.text(0.10, 0.9, "Jahr 2015 = 100", transform=ax.transAxes, fontsize=size, verticalalignment='top',
            bbox=dict(facecolor='none', edgecolor='black', boxstyle='round,pad=0.3', lw=2))

    # Diagramm als Bild exporieren und Auflösung definieren  
    plt.savefig(f'{pfad}{indexart} {wert} {title}.png', dpi=300, bbox_inches='tight')
# Out:
# Gesamt
# 118.4
# Nahrung
# 129.2
# Alkohol_Tabak
# 123.1
# Kleidung
# 103.4
# Wohnen
# 119.5
# Haushalt
# 113.5
# Gesundheit
# 107.6
# Verkehr
# 120.6
# Post_Internet
# 94.0
# Freizeit
# 120.8
# Bildung
# 106.1
# Gastgewerbe
# 125.1
# andere_Waren_Dienstleistungen
# 114.6
# Geldmenge_M1
# nan
# Geldmenge_M2
# nan
# Geldmenge_M3
# nan
